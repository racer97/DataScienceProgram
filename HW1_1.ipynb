# %%
import pandas as pd

# %%
df = pd.read_csv('Class1/state.csv')

# %%
df.head()
# Out:
#         State  Population  Murder.Rate Abbreviation
# 0     Alabama     4779736          5.7           AL
# 1      Alaska      710231          5.6           AK
# 2     Arizona     6392017          4.7           AZ
# 3    Arkansas     2915918          5.6           AR
# 4  California    37253956          4.4           CA

# %%
df.dtypes
# Out:
# State            object
# Population        int64
# Murder.Rate     float64
# Abbreviation     object
# dtype: object

# %%
(df.isnull().sum(axis=0))/len(df)
# Out:
# State           0.0
# Population      0.0
# Murder.Rate     0.0
# Abbreviation    0.0
# dtype: float64

# %%
df.describe()
# Out:
#          Population  Murder.Rate
# count  5.000000e+01    50.000000
# mean   6.162876e+06     4.066000
# std    6.848235e+06     1.915736
# min    5.636260e+05     0.900000
# 25%    1.833004e+06     2.425000
# 50%    4.436370e+06     4.000000
# 75%    6.680312e+06     5.550000
# max    3.725396e+07    10.300000

# %%
df.hist(bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119f1f470>,
# ...
#       dtype=object)

# %%
df_cat = df.select_dtypes(include=object)
print(df_cat['State'].value_counts())
print(df_cat['Abbreviation'].value_counts())
# Out:
# Washington        1
# New Hampshire     1
# Oklahoma          1
# Kentucky          1
# Indiana           1
# Virginia          1
# Alaska            1
# Iowa              1
# West Virginia     1
# Wisconsin         1
# Nevada            1
# Idaho             1
# Utah              1
# Colorado          1
# Texas             1
# Montana           1
# North Carolina    1
# Connecticut       1
# Massachusetts     1
# South Dakota      1
# Minnesota         1
# Tennessee         1
# Hawaii            1
# Georgia           1
# Ohio              1
# Delaware          1
# Michigan          1
# Arizona           1
# Rhode Island      1
# Wyoming           1
# California        1
# Nebraska          1
# New Mexico        1
# Mississippi       1
# Maryland          1
# Kansas            1
# Louisiana         1
# North Dakota      1
# Pennsylvania      1
# Maine             1
# Oregon            1
# New Jersey        1
# Florida           1
# Missouri          1
# Alabama           1
# ...

# %%
df.plot.bar(x='Abbreviation', y='Murder.Rate')

# %%
df.plot.scatter(x='Population', y = 'Murder.Rate')

# %% [markdown]
# 1. The state with highest murder rate is Louisiana, the lowest is New Hampshire.
# 2. The minimum murder rate is 0.9% while the highest is 10.3%
# 3. Population and murder rate have no obvious relationship.

# %%
df
# Out:
#              State  Population  Murder.Rate Abbreviation
# 0          Alabama     4779736          5.7           AL
# 1           Alaska      710231          5.6           AK
# 2          Arizona     6392017          4.7           AZ
# 3         Arkansas     2915918          5.6           AR
# 4       California    37253956          4.4           CA
# 5         Colorado     5029196          2.8           CO
# 6      Connecticut     3574097          2.4           CT
# 7         Delaware      897934          5.8           DE
# 8          Florida    18801310          5.8           FL
# 9          Georgia     9687653          5.7           GA
# 10          Hawaii     1360301          1.8           HI
# 11           Idaho     1567582          2.0           ID
# 12        Illinois    12830632          5.3           IL
# 13         Indiana     6483802          5.0           IN
# 14            Iowa     3046355          1.9           IA
# ...
