# %%
import pandas as pd

# %%
df = pd.read_csv('Class1/loans_income.csv')

# %%
df.head()
# Out:
#         x
# 0   67000
# 1   52000
# 2  100000
# 3   78762
# 4   37041

# %%
sp1 = df.sample(n=1000)
sp1
# Out:
#             x
# 44064   50000
# 32197   55000
# 28920   45000
# 12879   56000
# 20446   90000
# 33247   32400
# 5777    64000
# 8947    58000
# 49877   24000
# 13191   62000
# 33209   49000
# 19463   85125
# 5911    45000
# 31653   92508
# 48623   62000
# 2074    40500
# 23292   38000
# 32930   40000
# 22898   68500
# 30989   40000
# 14458   18000
# 36282  144799
# 35531   80000
# 30321   40200
# 27386   86000
# 6458    33000
# 8985    68500
# 32832   74000
# 20262   65000
# 44849   60000
# ...       ...
# 33213   45000
# 40504   25000
# 41091   25000
# 842     75000
# 11290  125000
# 11638   90000
# 25428   30000
# 16811   30000
# 16382   30000
# 37723   67000
# 15939   45839
# 22422   25576
# 31957   12000
# 39128   40000
# 39767   26540
# 9940   122694
# 23768   85000
# 41522   50000
# 3048    50000
# 39597   75000
# 29220   32000
# 8839    75000
# 27402   35000
# 43410   53260
# 17027   94000
# 28416   74000
# 40997   33000
# 25433  110000
# 28706   79500
# 32803   56000
#
# ...

# %%
list1 = [10, 50, 100, 1000]
for i in list1:
    for j in range(i):
        sp2 = df.sample(n = 10, replace=True)
        print(sp2)
        sp3 = df.sample(n = 100, replace=True)
        print(sp3)
# Out:
#             x
# 18525   65000
# 2639    45000
# 8935    75000
# 10584   71000
# 14884   45000
# 31172   50000
# 33639   84500
# 13434  138000
# 40427   38000
# 49818  104500
#             x
# 45906   61500
# 46420   45000
# 7941    52000
# 33934   80000
# 46501  120000
# 23308  135000
# 46777   35000
# 9295   140000
# 39063   60000
# 36635   95000
# 27211   41700
# 34991  100000
# 6622   110000
# 6578    58000
# 25926   57000
# 5214    36000
# 42712   36000
# 25612   42000
# 34200   90000
# 11868   70000
# 38142   83004
# 35667   40000
# 37046   38000
# 27699   75000
# 40308   33000
# 17961   35000
# 49984   65000
# 43719   55000
# 45916   60000
# 6613    70000
# ...       ...
# 44801   40000
# 18844   53940
# 19669   70000
# 39642   28000
# 36508   45000
# 9144    70000
# 29726   59000
# 19708   40000
# 5421    85000
# 45942   45409
# 13702   42000
# 2678   107000
# 28815   70000
# 3082    92000
# 2908    38000
# 507     35000
# 35786   95000
# 37445  100000
# 14783   98000
# ...
